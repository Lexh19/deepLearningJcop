# %%
import numpy as np  # Import library numpy untuk operasi numerik
import pandas as pd  # Import library pandas untuk manipulasi data

# %%
import json  # Import library json untuk membaca data dari file JSON

with open('filtered_ti_usu_dataset.json', 'r') as f:
    data = json.load(f)  # Membaca data dari file JSON dan menyimpannya dalam variabel 'data'

df = pd.DataFrame(data['intents'])  # Membuat DataFrame dari bagian 'intents' dalam data JSON
df
# Out:
#                         tag  \
# 0                    sapaan
# 1           selamat_tinggal
# 2               terimakasih
# 3            tentang_ti_usu
# 4                 visi_misi
# 5               mata_kuliah
# 6                 fasilitas
# 7            profil_lulusan
# 8           jadwal_akademik
# 9                    kontak
# 10                 beasiswa
# 11      struktur_organisasi
# 12                pendanaan
# 13            fasilitas_lab
# 14              ruang_kelas
# 15          layanan_digital
# 16         sarana_prasarana
# 17  jadwal_akademik_lengkap
# 18           kurikulum_kkni
# 19                    dosen
# 20                 keuangan
# 21         program_unggulan
# 22             fasilitas_ti
# 23         alur_pendaftaran
# 24            kurikulum_obe
# 25        mata_kuliah_wajib
# 26      mata_kuliah_pilihan
# 27                praktikum
# 28           profil_lulusan
# 29   mata_kuliah_semester_2
# 30   mata_kuliah_semester_4
# 31           dosen_pengampu
# 32    mata_kuliah_praktikum
# 33  deskripsi_program_studi
# 34  visi_misi_program_studi
# 35       struktur_kurikulum
# 36        persyaratan_masuk
# 37      karir_setelah_lulus
# 38  fasilitas_program_studi
# 39     kontak_program_studi
# 40           informasi_mbkm
# 41   jadwal_semester_ganjil
# 42    jadwal_semester_genap
# 43           jadwal_uts_uas
# 44      registrasi_akademik
# 45           libur_akademik
# 46                     mbkm
#
#                                              patterns  \
# 0   [Hai, Halo, Selamat pagi, Selamat siang, Selam...
# 1                     [Sampai jumpa, Selamat tinggal]
# 2   [Terimakasih, Terimakasih banyak, Terimakasih ...
# 3   [Apa itu TI USU?, Jelaskan tentang TI USU, TI ...
# 4   [Apa visi dan misi TI USU?, Jelaskan visi TI U...
# 5   [Apa saja mata kuliah di TI USU?, Apa yang dip...
# 6   [Apa fasilitas yang tersedia di TI USU?, Apaka...
# 7   [Apa profil lulusan TI USU?, Lulusan TI USU bi...
# 8   [Kapan perkuliahan dimulai?, Jelaskan jadwal a...
# 9   [Bagaimana cara menghubungi TI USU?, Apakah ad...
# 10  [Apakah TI USU menawarkan beasiswa?, Beasiswa ...
# 11  [Siapa ketua TI USU?, Jelaskan struktur organi...
# 12  [Bagaimana sumber pendanaan di TI USU?, Dari m...
# 13  [Apa saja fasilitas laboratorium di TI USU?, J...
# 14  [Berapa ruang kelas yang tersedia di TI USU?, ...
# 15  [Apa layanan digital yang disediakan TI USU?, ...
# 16  [Apa sarana prasarana TI USU?, Jelaskan fasili...
# 17  [Apa jadwal akademik terbaru?, Bisa berikan ka...
# 18  [Apa kurikulum TI USU?, Jelaskan kurikulum KKN...
# 19  [Siapa saja dosen TI USU?, Jelaskan daftar pen...
# 20  [Berapa biaya kuliah di TI USU?, Apakah ada ri...
# 21  [Apa program unggulan di TI USU?, Apakah TI US...
# 22  [Fasilitas apa saja yang disediakan TI USU?, A...
# 23  [Bagaimana cara mendaftar di TI USU?, Apakah a...
# 24  [Apa itu kurikulum OBE?, Jelaskan tentang KKNI...
# 25  [Apa saja mata kuliah wajib di TI USU?, Mata k...
# 26  [Apa mata kuliah pilihan di TI USU?, Apakah ad...
# 27  [Apakah ada praktikum di TI USU?, Jelaskan ten...
# 28  [Apa profil lulusan TI USU?, Lulusan TI USU bi...
# 29  [Apa saja mata kuliah semester 2 di TI USU?, M...
# 30  [Apa saja mata kuliah semester 4 di TI USU?, M...
# 31  [Siapa dosen yang mengajar Pemrograman Web Lan...
# 32  [Apa saja mata kuliah praktikum di TI USU?, Pr...
# 33  [Apa deskripsi singkat program studi TI USU?, ...
# 34  [Apa visi TI USU?, Jelaskan misi program studi...
# 35  [Apa saja mata kuliah wajib di TI USU?, Bagaim...
# 36  [Apa syarat masuk TI USU?, Jelaskan persyarata...
# 37  [Apa peluang karir untuk lulusan TI USU?, Kari...
# 38  [Apa saja fasilitas di TI USU?, Fasilitas apa ...
# 39  [Bagaimana cara menghubungi TI USU?, Kontak TI...
# 40  [Apa itu program MBKM di TI USU?, Apa peluang ...
# 41  [Kapan awal dan akhir semester ganjil?, Apa ja...
# 42  [Kapan awal dan akhir semester genap?, Apa jad...
# 43  [Kapan UTS dan UAS semester ganjil?, Jelaskan ...
# 44  [Kapan periode registrasi akademik?, Apa jadwa...
# 45  [Kapan libur semester?, Apa saja hari libur na...
# 46  [Apa jadwal MBKM di TI USU?, Jelaskan jadwal k...
#
#                                             responses
# 0   [Halo! Selamat datang di chatbot TI USU. Ada y...
# 1   [Sampai jumpa lagi, Semoga bahagia selalu., Se...
# 2   [Terimakasih kembali, Sama-sama. Siap membantu...
# 3   [Program Studi Teknologi Informasi di Universi...
# 4   [Visi TI USU: Menjadi Program Studi yang unggu...
# 5   [Mata kuliah di TI USU mencakup:\n1. Pengantar...
# 6   [TI USU memiliki fasilitas seperti:\n1. Labora...
# 7   [Profil lulusan TI USU meliputi:\n1. System An...
# 8   [Semester ganjil dimulai pada bulan Agustus, d...
# 9   [Anda dapat menghubungi TI USU melalui email: ...
# 10  [TI USU menawarkan beberapa beasiswa, termasuk...
# 11  [Ketua Program Studi: Romi Fadillah Rahmat, B....
# 12  [Sumber pendanaan TI USU meliputi:\n1. Dana SP...
# 13  [TI USU memiliki beberapa laboratorium:\n1. La...
# 14  [TI USU memiliki ruang kelas dengan daya tampu...
# 15  [TI USU memiliki layanan digital seperti:\n1. ...
# 16  [Sarana dan prasarana TI USU meliputi:\n1. Rua...
# 17  [Kalender akademik 2024-2025:\n- Semester ganj...
# 18  [TI USU menggunakan kurikulum berbasis KKNI (K...
# 19  [Beberapa dosen TI USU:\n- Prof. Dr. Opim Sali...
# 20  [Biaya kuliah di TI USU menggunakan sistem UKT...
# 21  [Program unggulan TI USU meliputi:\n1. Data Sc...
# 22  [Fasilitas TI USU:\n1. Laboratorium Komputer d...
# 23  [Untuk mendaftar:\n1. Ikuti SNMPTN/SBMPTN.\n2....
# 24  [Kurikulum TI USU berbasis Outcome-Based Educa...
# 25  [Mata kuliah wajib di TI USU meliputi:\n1. Das...
# 26  [Mata kuliah pilihan di TI USU meliputi:\n1. E...
# 27  [TI USU menyediakan berbagai praktikum untuk m...
# 28  [Lulusan TI USU memiliki profil sebagai:\n1. P...
# 29  [Mata kuliah semester 2 TI USU meliputi:\n1. P...
# 30  [Mata kuliah semester 4 TI USU meliputi:\n1. A...
# 31  [Dosen pengampu Pemrograman Web Lanjutan:\n- M...
# 32  [TI USU menyediakan beberapa praktikum, termas...
# 33  [Program Studi Teknologi Informasi Universitas...
# 34  [Visi: Menjadi program studi unggulan dalam pe...
# 35  [Struktur Kurikulum TI USU terdiri dari:\n- Ma...
# 36  [Persyaratan masuk TI USU meliputi:\n1. Lulus ...
# 37  [Lulusan TI USU memiliki peluang karir seperti...
# 38  [Fasilitas di TI USU meliputi:\n- Laboratorium...
# 39  [Kontak TI USU:\n- Alamat: Fakultas Ilmu Kompu...
# 40  [Informasi MBKM di TI USU:\n- Program Pertukar...
# 41  [Semester ganjil dimulai pada 19 Agustus 2024 ...
# 42  [Semester genap dimulai pada 10 Februari 2025 ...
# 43  [UTS semester ganjil dijadwalkan pada 7–18 Okt...
# 44  [Registrasi akademik semester ganjil berlangsu...
# 45  [Libur semester genap berlangsung dari 28 Juni...
# 46  [Pelaksanaan MBKM untuk semester ganjil berlan...

# %%
dic = {"tag":[], "patterns":[], "responses":[]}  # Membuat dictionary kosong untuk menyimpan data yang akan diubah ke DataFrame
for i in range(len(df)):
    ptrns = df[df.index == i]['patterns'].values[0]  # Mengambil pola (patterns) dari DataFrame
    rspns = df[df.index == i]['responses'].values[0]  # Mengambil respons dari DataFrame
    tag = df[df.index == i]['tag'].values[0]  # Mengambil tag dari DataFrame
    for j in range(len(ptrns)):
        dic['tag'].append(tag)  # Menambahkan tag ke dalam dictionary
        dic['patterns'].append(ptrns[j])  # Menambahkan pola ke dalam dictionary
        dic['responses'].append(rspns)  # Menambahkan respons ke dalam dictionary

df = pd.DataFrame.from_dict(dic)  # Membuat DataFrame baru dari dictionary
pd.set_option("display.max_rows", None)  # Menampilkan semua baris DataFrame ketika ditampilkan
df  # Menampilkan DataFrame
# Out:
#                          tag  \
# 0                     sapaan
# 1                     sapaan
# 2                     sapaan
# 3                     sapaan
# 4                     sapaan
# 5                     sapaan
# 6                     sapaan
# 7                     sapaan
# 8            selamat_tinggal
# 9            selamat_tinggal
# 10               terimakasih
# 11               terimakasih
# 12               terimakasih
# 13               terimakasih
# 14            tentang_ti_usu
# 15            tentang_ti_usu
# 16            tentang_ti_usu
# 17            tentang_ti_usu
# 18                 visi_misi
# 19                 visi_misi
# 20                 visi_misi
# 21               mata_kuliah
# 22               mata_kuliah
# 23               mata_kuliah
# 24                 fasilitas
# 25                 fasilitas
# 26                 fasilitas
# 27            profil_lulusan
# 28            profil_lulusan
# 29            profil_lulusan
# 30           jadwal_akademik
# 31           jadwal_akademik
# 32           jadwal_akademik
# 33                    kontak
# 34                    kontak
# 35                    kontak
# 36                  beasiswa
# 37                  beasiswa
# 38                  beasiswa
# 39       struktur_organisasi
# 40       struktur_organisasi
# 41       struktur_organisasi
# 42                 pendanaan
# 43                 pendanaan
# 44                 pendanaan
# 45             fasilitas_lab
# 46             fasilitas_lab
# 47             fasilitas_lab
# 48               ruang_kelas
# 49               ruang_kelas
# 50               ruang_kelas
# 51           layanan_digital
# 52           layanan_digital
# 53           layanan_digital
# 54          sarana_prasarana
# 55          sarana_prasarana
# 56          sarana_prasarana
# 57   jadwal_akademik_lengkap
# 58   jadwal_akademik_lengkap
# 59   jadwal_akademik_lengkap
# 60            kurikulum_kkni
# 61            kurikulum_kkni
# 62            kurikulum_kkni
# 63                     dosen
# 64                     dosen
# 65                     dosen
# 66                  keuangan
# 67                  keuangan
# 68                  keuangan
# 69          program_unggulan
# 70          program_unggulan
# 71          program_unggulan
# 72              fasilitas_ti
# 73              fasilitas_ti
# 74              fasilitas_ti
# 75          alur_pendaftaran
# 76          alur_pendaftaran
# 77          alur_pendaftaran
# 78             kurikulum_obe
# 79             kurikulum_obe
# 80             kurikulum_obe
# 81         mata_kuliah_wajib
# 82         mata_kuliah_wajib
# 83         mata_kuliah_wajib
# 84       mata_kuliah_pilihan
# 85       mata_kuliah_pilihan
# 86       mata_kuliah_pilihan
# 87                 praktikum
# 88                 praktikum
# 89                 praktikum
# 90            profil_lulusan
# 91            profil_lulusan
# 92            profil_lulusan
# 93    mata_kuliah_semester_2
# 94    mata_kuliah_semester_2
# 95    mata_kuliah_semester_4
# 96    mata_kuliah_semester_4
# 97            dosen_pengampu
# 98            dosen_pengampu
# 99     mata_kuliah_praktikum
# 100    mata_kuliah_praktikum
# 101  deskripsi_program_studi
# 102  deskripsi_program_studi
# 103  deskripsi_program_studi
# 104  visi_misi_program_studi
# 105  visi_misi_program_studi
# 106  visi_misi_program_studi
# 107       struktur_kurikulum
# 108       struktur_kurikulum
# 109       struktur_kurikulum
# 110        persyaratan_masuk
# 111        persyaratan_masuk
# 112        persyaratan_masuk
# 113      karir_setelah_lulus
# 114      karir_setelah_lulus
# 115      karir_setelah_lulus
# 116  fasilitas_program_studi
# 117  fasilitas_program_studi
# 118  fasilitas_program_studi
# 119     kontak_program_studi
# 120     kontak_program_studi
# 121     kontak_program_studi
# 122           informasi_mbkm
# 123           informasi_mbkm
# 124           informasi_mbkm
# 125   jadwal_semester_ganjil
# 126   jadwal_semester_ganjil
# 127    jadwal_semester_genap
# 128    jadwal_semester_genap
# 129           jadwal_uts_uas
# 130           jadwal_uts_uas
# 131      registrasi_akademik
# 132      registrasi_akademik
# 133           libur_akademik
# 134           libur_akademik
# 135                     mbkm
# 136                     mbkm
#
#                                               patterns  \
# 0                                                  Hai
# 1                                                 Halo
# 2                                         Selamat pagi
# 3                                        Selamat siang
# 4                                         Selamat sore
# 5                                                 halo
# 6                                                hallo
# 7                                                  hay
# 8                                         Sampai jumpa
# 9                                      Selamat tinggal
# 10                                         Terimakasih
# 11                                  Terimakasih banyak
# 12                        Terimakasih atas bantuannya.
# 13                       Terimakasih. Sangat membantu.
# 14                                     Apa itu TI USU?
# 15                             Jelaskan tentang TI USU
# 16                                     TI USU itu apa?
# 17                         Apa yang ditawarkan TI USU?
# 18                           Apa visi dan misi TI USU?
# 19                               Jelaskan visi TI USU.
# 20                  Misi apa yang diusung oleh TI USU?
# 21                     Apa saja mata kuliah di TI USU?
# 22                      Apa yang dipelajari di TI USU?
# 23               Mata kuliah utama di TI USU apa saja?
# 24              Apa fasilitas yang tersedia di TI USU?
# 25                Apakah TI USU memiliki laboratorium?
# 26                       Fasilitas apa saja di TI USU?
# 27                          Apa profil lulusan TI USU?
# 28                Lulusan TI USU bisa bekerja di mana?
# 29                           Deskripsi lulusan TI USU?
# 30                          Kapan perkuliahan dimulai?
# 31                    Jelaskan jadwal akademik TI USU.
# 32                         Kapan UTS dan UAS diadakan?
# 33                  Bagaimana cara menghubungi TI USU?
# 34                    Apakah ada nomor telepon TI USU?
# 35                               Dimana lokasi TI USU?
# 36                  Apakah TI USU menawarkan beasiswa?
# 37                        Beasiswa apa saja di TI USU?
# 38      Bagaimana cara mendapatkan beasiswa di TI USU?
# 39                                 Siapa ketua TI USU?
# 40                Jelaskan struktur organisasi TI USU.
# 41                     Apakah ada daftar dosen TI USU?
# 42               Bagaimana sumber pendanaan di TI USU?
# 43                      Dari mana dana TI USU berasal?
# 44                  Apakah ada detail keuangan TI USU?
# 45          Apa saja fasilitas laboratorium di TI USU?
# 46                   Jelaskan fasilitas lab di TI USU.
# 47               Berapa jumlah laboratorium di TI USU?
# 48         Berapa ruang kelas yang tersedia di TI USU?
# 49                Apa fasilitas ruang kelas di TI USU?
# 50             Jelaskan tentang ruang kelas di TI USU.
# 51         Apa layanan digital yang disediakan TI USU?
# 52         Layanan online apa yang tersedia di TI USU?
# 53                  Bagaimana mengakses portal TI USU?
# 54                        Apa sarana prasarana TI USU?
# 55                  Jelaskan fasilitas umum di TI USU.
# 56   Apa saja yang tersedia untuk mendukung belajar...
# 57                        Apa jadwal akademik terbaru?
# 58              Bisa berikan kalender akademik TI USU?
# 59                               Kapan libur semester?
# 60                               Apa kurikulum TI USU?
# 61                  Jelaskan kurikulum KKNI di TI USU.
# 62                      Apakah TI USU menggunakan OBE?
# 63                            Siapa saja dosen TI USU?
# 64                 Jelaskan daftar pengajar di TI USU.
# 65                      Apakah ada profesor di TI USU?
# 66                      Berapa biaya kuliah di TI USU?
# 67                   Apakah ada rincian UKT di TI USU?
# 68                Bagaimana sistem keuangan mahasiswa?
# 69                     Apa program unggulan di TI USU?
# 70                Apakah TI USU memiliki fokus khusus?
# 71                    Program andalan TI USU apa saja?
# 72          Fasilitas apa saja yang disediakan TI USU?
# 73                  Apakah ada laboratorium di TI USU?
# 74               Bagaimana fasilitas mahasiswa TI USU?
# 75                 Bagaimana cara mendaftar di TI USU?
# 76                   Apakah ada informasi pendaftaran?
# 77                         Jelaskan alur masuk TI USU.
# 78                              Apa itu kurikulum OBE?
# 79                       Jelaskan tentang KKNI ke OBE.
# 80       Bagaimana kurikulum TI USU diimplementasikan?
# 81               Apa saja mata kuliah wajib di TI USU?
# 82                   Mata kuliah inti TI USU apa saja?
# 83             Jelaskan mata kuliah di kurikulum baru.
# 84                  Apa mata kuliah pilihan di TI USU?
# 85                     Apakah ada mata kuliah pilihan?
# 86               Mata kuliah tambahan TI USU apa saja?
# 87                     Apakah ada praktikum di TI USU?
# 88               Jelaskan tentang praktikum di TI USU.
# 89                   Praktikum apa saja yang tersedia?
# 90                          Apa profil lulusan TI USU?
# 91                Lulusan TI USU bisa bekerja di mana?
# 92              Jelaskan profil lulusan kurikulum OBE.
# 93          Apa saja mata kuliah semester 2 di TI USU?
# 94                 Mata kuliah di semester 2 apa saja?
# 95          Apa saja mata kuliah semester 4 di TI USU?
# 96                 Mata kuliah di semester 4 apa saja?
# 97   Siapa dosen yang mengajar Pemrograman Web Lanj...
# 98             Siapa dosen pengampu Sistem Basis Data?
# 99           Apa saja mata kuliah praktikum di TI USU?
# 100             Praktikum apa yang tersedia di TI USU?
# 101        Apa deskripsi singkat program studi TI USU?
# 102             Jelaskan tentang program studi TI USU.
# 103                            Apa fokus utama TI USU?
# 104                                   Apa visi TI USU?
# 105                Jelaskan misi program studi TI USU.
# 106                                 Apa tujuan TI USU?
# 107              Apa saja mata kuliah wajib di TI USU?
# 108               Bagaimana struktur kurikulum TI USU?
# 109                 Apa mata kuliah pilihan di TI USU?
# 110                           Apa syarat masuk TI USU?
# 111                 Jelaskan persyaratan masuk TI USU.
# 112                Bagaimana cara mendaftar ke TI USU?
# 113            Apa peluang karir untuk lulusan TI USU?
# 114              Karir apa yang relevan dengan TI USU?
# 115                    Lulusan TI USU bekerja di mana?
# 116                      Apa saja fasilitas di TI USU?
# 117    Fasilitas apa yang mendukung belajar di TI USU?
# 118                 Apakah ada laboratorium di TI USU?
# 119                 Bagaimana cara menghubungi TI USU?
# 120                            Kontak TI USU apa saja?
# 121                              Dimana lokasi TI USU?
# 122                    Apa itu program MBKM di TI USU?
# 123                      Apa peluang magang di TI USU?
# 124           Apakah ada program pertukaran mahasiswa?
# 125              Kapan awal dan akhir semester ganjil?
# 126              Apa jadwal semester ganjil 2024/2025?
# 127               Kapan awal dan akhir semester genap?
# 128               Apa jadwal semester genap 2024/2025?
# 129                 Kapan UTS dan UAS semester ganjil?
# 130                  Jelaskan jadwal UTS dan UAS 2024.
# 131                 Kapan periode registrasi akademik?
# 132                         Apa jadwal pembayaran UKT?
# 133                              Kapan libur semester?
# 134  Apa saja hari libur nasional di kalender akade...
# 135                         Apa jadwal MBKM di TI USU?
# 136           Jelaskan jadwal kegiatan MBKM 2024/2025.
#
#                                              responses
# 0    [Halo! Selamat datang di chatbot TI USU. Ada y...
# 1    [Halo! Selamat datang di chatbot TI USU. Ada y...
# 2    [Halo! Selamat datang di chatbot TI USU. Ada y...
# 3    [Halo! Selamat datang di chatbot TI USU. Ada y...
# 4    [Halo! Selamat datang di chatbot TI USU. Ada y...
# 5    [Halo! Selamat datang di chatbot TI USU. Ada y...
# 6    [Halo! Selamat datang di chatbot TI USU. Ada y...
# 7    [Halo! Selamat datang di chatbot TI USU. Ada y...
# 8    [Sampai jumpa lagi, Semoga bahagia selalu., Se...
# 9    [Sampai jumpa lagi, Semoga bahagia selalu., Se...
# 10   [Terimakasih kembali, Sama-sama. Siap membantu...
# 11   [Terimakasih kembali, Sama-sama. Siap membantu...
# 12   [Terimakasih kembali, Sama-sama. Siap membantu...
# 13   [Terimakasih kembali, Sama-sama. Siap membantu...
# 14   [Program Studi Teknologi Informasi di Universi...
# 15   [Program Studi Teknologi Informasi di Universi...
# 16   [Program Studi Teknologi Informasi di Universi...
# 17   [Program Studi Teknologi Informasi di Universi...
# 18   [Visi TI USU: Menjadi Program Studi yang unggu...
# 19   [Visi TI USU: Menjadi Program Studi yang unggu...
# 20   [Visi TI USU: Menjadi Program Studi yang unggu...
# 21   [Mata kuliah di TI USU mencakup:\n1. Pengantar...
# 22   [Mata kuliah di TI USU mencakup:\n1. Pengantar...
# 23   [Mata kuliah di TI USU mencakup:\n1. Pengantar...
# 24   [TI USU memiliki fasilitas seperti:\n1. Labora...
# 25   [TI USU memiliki fasilitas seperti:\n1. Labora...
# 26   [TI USU memiliki fasilitas seperti:\n1. Labora...
# 27   [Profil lulusan TI USU meliputi:\n1. System An...
# 28   [Profil lulusan TI USU meliputi:\n1. System An...
# 29   [Profil lulusan TI USU meliputi:\n1. System An...
# 30   [Semester ganjil dimulai pada bulan Agustus, d...
# 31   [Semester ganjil dimulai pada bulan Agustus, d...
# 32   [Semester ganjil dimulai pada bulan Agustus, d...
# 33   [Anda dapat menghubungi TI USU melalui email: ...
# 34   [Anda dapat menghubungi TI USU melalui email: ...
# 35   [Anda dapat menghubungi TI USU melalui email: ...
# 36   [TI USU menawarkan beberapa beasiswa, termasuk...
# 37   [TI USU menawarkan beberapa beasiswa, termasuk...
# 38   [TI USU menawarkan beberapa beasiswa, termasuk...
# 39   [Ketua Program Studi: Romi Fadillah Rahmat, B....
# 40   [Ketua Program Studi: Romi Fadillah Rahmat, B....
# 41   [Ketua Program Studi: Romi Fadillah Rahmat, B....
# 42   [Sumber pendanaan TI USU meliputi:\n1. Dana SP...
# 43   [Sumber pendanaan TI USU meliputi:\n1. Dana SP...
# 44   [Sumber pendanaan TI USU meliputi:\n1. Dana SP...
# 45   [TI USU memiliki beberapa laboratorium:\n1. La...
# 46   [TI USU memiliki beberapa laboratorium:\n1. La...
# 47   [TI USU memiliki beberapa laboratorium:\n1. La...
# 48   [TI USU memiliki ruang kelas dengan daya tampu...
# 49   [TI USU memiliki ruang kelas dengan daya tampu...
# 50   [TI USU memiliki ruang kelas dengan daya tampu...
# 51   [TI USU memiliki layanan digital seperti:\n1. ...
# 52   [TI USU memiliki layanan digital seperti:\n1. ...
# 53   [TI USU memiliki layanan digital seperti:\n1. ...
# 54   [Sarana dan prasarana TI USU meliputi:\n1. Rua...
# 55   [Sarana dan prasarana TI USU meliputi:\n1. Rua...
# 56   [Sarana dan prasarana TI USU meliputi:\n1. Rua...
# 57   [Kalender akademik 2024-2025:\n- Semester ganj...
# 58   [Kalender akademik 2024-2025:\n- Semester ganj...
# 59   [Kalender akademik 2024-2025:\n- Semester ganj...
# 60   [TI USU menggunakan kurikulum berbasis KKNI (K...
# 61   [TI USU menggunakan kurikulum berbasis KKNI (K...
# 62   [TI USU menggunakan kurikulum berbasis KKNI (K...
# 63   [Beberapa dosen TI USU:\n- Prof. Dr. Opim Sali...
# 64   [Beberapa dosen TI USU:\n- Prof. Dr. Opim Sali...
# 65   [Beberapa dosen TI USU:\n- Prof. Dr. Opim Sali...
# 66   [Biaya kuliah di TI USU menggunakan sistem UKT...
# 67   [Biaya kuliah di TI USU menggunakan sistem UKT...
# 68   [Biaya kuliah di TI USU menggunakan sistem UKT...
# 69   [Program unggulan TI USU meliputi:\n1. Data Sc...
# 70   [Program unggulan TI USU meliputi:\n1. Data Sc...
# 71   [Program unggulan TI USU meliputi:\n1. Data Sc...
# 72   [Fasilitas TI USU:\n1. Laboratorium Komputer d...
# 73   [Fasilitas TI USU:\n1. Laboratorium Komputer d...
# 74   [Fasilitas TI USU:\n1. Laboratorium Komputer d...
# 75   [Untuk mendaftar:\n1. Ikuti SNMPTN/SBMPTN.\n2....
# 76   [Untuk mendaftar:\n1. Ikuti SNMPTN/SBMPTN.\n2....
# 77   [Untuk mendaftar:\n1. Ikuti SNMPTN/SBMPTN.\n2....
# 78   [Kurikulum TI USU berbasis Outcome-Based Educa...
# 79   [Kurikulum TI USU berbasis Outcome-Based Educa...
# 80   [Kurikulum TI USU berbasis Outcome-Based Educa...
# 81   [Mata kuliah wajib di TI USU meliputi:\n1. Das...
# 82   [Mata kuliah wajib di TI USU meliputi:\n1. Das...
# 83   [Mata kuliah wajib di TI USU meliputi:\n1. Das...
# 84   [Mata kuliah pilihan di TI USU meliputi:\n1. E...
# 85   [Mata kuliah pilihan di TI USU meliputi:\n1. E...
# 86   [Mata kuliah pilihan di TI USU meliputi:\n1. E...
# 87   [TI USU menyediakan berbagai praktikum untuk m...
# 88   [TI USU menyediakan berbagai praktikum untuk m...
# 89   [TI USU menyediakan berbagai praktikum untuk m...
# 90   [Lulusan TI USU memiliki profil sebagai:\n1. P...
# 91   [Lulusan TI USU memiliki profil sebagai:\n1. P...
# 92   [Lulusan TI USU memiliki profil sebagai:\n1. P...
# 93   [Mata kuliah semester 2 TI USU meliputi:\n1. P...
# 94   [Mata kuliah semester 2 TI USU meliputi:\n1. P...
# 95   [Mata kuliah semester 4 TI USU meliputi:\n1. A...
# 96   [Mata kuliah semester 4 TI USU meliputi:\n1. A...
# 97   [Dosen pengampu Pemrograman Web Lanjutan:\n- M...
# 98   [Dosen pengampu Pemrograman Web Lanjutan:\n- M...
# 99   [TI USU menyediakan beberapa praktikum, termas...
# 100  [TI USU menyediakan beberapa praktikum, termas...
# 101  [Program Studi Teknologi Informasi Universitas...
# 102  [Program Studi Teknologi Informasi Universitas...
# 103  [Program Studi Teknologi Informasi Universitas...
# 104  [Visi: Menjadi program studi unggulan dalam pe...
# 105  [Visi: Menjadi program studi unggulan dalam pe...
# 106  [Visi: Menjadi program studi unggulan dalam pe...
# 107  [Struktur Kurikulum TI USU terdiri dari:\n- Ma...
# 108  [Struktur Kurikulum TI USU terdiri dari:\n- Ma...
# 109  [Struktur Kurikulum TI USU terdiri dari:\n- Ma...
# 110  [Persyaratan masuk TI USU meliputi:\n1. Lulus ...
# 111  [Persyaratan masuk TI USU meliputi:\n1. Lulus ...
# 112  [Persyaratan masuk TI USU meliputi:\n1. Lulus ...
# 113  [Lulusan TI USU memiliki peluang karir seperti...
# 114  [Lulusan TI USU memiliki peluang karir seperti...
# 115  [Lulusan TI USU memiliki peluang karir seperti...
# 116  [Fasilitas di TI USU meliputi:\n- Laboratorium...
# 117  [Fasilitas di TI USU meliputi:\n- Laboratorium...
# 118  [Fasilitas di TI USU meliputi:\n- Laboratorium...
# 119  [Kontak TI USU:\n- Alamat: Fakultas Ilmu Kompu...
# 120  [Kontak TI USU:\n- Alamat: Fakultas Ilmu Kompu...
# 121  [Kontak TI USU:\n- Alamat: Fakultas Ilmu Kompu...
# 122  [Informasi MBKM di TI USU:\n- Program Pertukar...
# 123  [Informasi MBKM di TI USU:\n- Program Pertukar...
# 124  [Informasi MBKM di TI USU:\n- Program Pertukar...
# 125  [Semester ganjil dimulai pada 19 Agustus 2024 ...
# 126  [Semester ganjil dimulai pada 19 Agustus 2024 ...
# 127  [Semester genap dimulai pada 10 Februari 2025 ...
# 128  [Semester genap dimulai pada 10 Februari 2025 ...
# 129  [UTS semester ganjil dijadwalkan pada 7–18 Okt...
# 130  [UTS semester ganjil dijadwalkan pada 7–18 Okt...
# 131  [Registrasi akademik semester ganjil berlangsu...
# 132  [Registrasi akademik semester ganjil berlangsu...
# 133  [Libur semester genap berlangsung dari 28 Juni...
# 134  [Libur semester genap berlangsung dari 28 Juni...
# 135  [Pelaksanaan MBKM untuk semester ganjil berlan...
# 136  [Pelaksanaan MBKM untuk semester ganjil berlan...

# %%
df.to_excel('dataset.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.to_excel('dataset.xlsx', index=False)
#
# File c:\Users\akmal\anaconda3\envs\jcopdl\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\akmal\anaconda3\envs\jcopdl\Lib\site-packages\pandas\core\generic.py:2417, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2404 from pandas.io.formats.excel import ExcelFormatter
#    2406 formatter = ExcelFormatter(
#    2407     df,
#    2408     na_rep=na_rep,
#    (...)
#    2415     inf_rep=inf_rep,
#    2416 )
# -> 2417 formatter.write(
#    2418     excel_writer,
#    2419     sheet_name=sheet_name,
#    2420     startrow=startrow,
#    2421     startcol=startcol,
#    2422     freeze_panes=freeze_panes,
#    2423     engine=engine,
#    2424     storage_options=storage_options,
#    2425     engine_kwargs=engine_kwargs,
#    2426 )
#
# File c:\Users\akmal\anaconda3\envs\jcopdl\Lib\site-packages\pandas\io\formats\excel.py:943, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     941     need_save = False
#     942 else:
# --> 943     writer = ExcelWriter(
#     944         writer,
#     945         engine=engine,
#     946         storage_options=storage_options,
#     947         engine_kwargs=engine_kwargs,
#     948     )
#     949     need_save = True
#     951 try:
#
# File c:\Users\akmal\anaconda3\envs\jcopdl\Lib\site-packages\pandas\io\excel\_openpyxl.py:57, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      44 def __init__(
#      45     self,
#      46     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)
#      55 ) -> None:
#      56     # Use the openpyxl module as the Excel writer.
# ---> 57     from openpyxl.workbook import Workbook
#      59     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      61     super().__init__(
#      62         path,
#      63         mode=mode,
#    (...)
#      66         engine_kwargs=engine_kwargs,
#      67     )
#
# ModuleNotFoundError: No module named 'openpyxl'

# %%
df['tag'].unique()
# Out:
# array(['sapaan', 'selamat_tinggal', 'terimakasih', 'tentang_ti_usu',
#        'visi_misi', 'mata_kuliah', 'fasilitas', 'profil_lulusan',
#        'jadwal_akademik', 'kontak', 'beasiswa', 'struktur_organisasi',
#        'pendanaan', 'fasilitas_lab', 'ruang_kelas', 'layanan_digital',
#        'sarana_prasarana', 'jadwal_akademik_lengkap', 'kurikulum_kkni',
#        'dosen', 'keuangan', 'program_unggulan', 'fasilitas_ti',
#        'alur_pendaftaran', 'kurikulum_obe', 'mata_kuliah_wajib',
#        'mata_kuliah_pilihan', 'praktikum', 'mata_kuliah_semester_2',
#        'mata_kuliah_semester_4', 'dosen_pengampu',
#        'mata_kuliah_praktikum', 'deskripsi_program_studi',
#        'visi_misi_program_studi', 'struktur_kurikulum',
#        'persyaratan_masuk', 'karir_setelah_lulus',
#        'fasilitas_program_studi', 'kontak_program_studi',
#        'informasi_mbkm', 'jadwal_semester_ganjil',
#        'jadwal_semester_genap', 'jadwal_uts_uas', 'registrasi_akademik',
#        'libur_akademik', 'mbkm'], dtype=object)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(lower=True, split=' ')
tokenizer.fit_on_texts(df['patterns'])
tokenizer.get_config()
# Out:
# {'num_words': None,
#  'filters': '!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',
#  'lower': True,
#  'split': ' ',
#  'char_level': False,
#  'oov_token': None,
#  'document_count': 137,
#  'word_counts': '{"hai": 1, "halo": 2, "selamat": 4, "pagi": 1, "siang": 1, "sore": 1, "hallo": 1, "hay": 1, "sampai": 1, "jumpa": 1, "tinggal": 1, "terimakasih": 4, "banyak": 1, "atas": 1, "bantuannya": 1, "sangat": 1, "membantu": 1, "apa": 55, "itu": 4, "ti": 95, "usu": 95, "jelaskan": 19, "tentang": 5, "yang": 14, "ditawarkan": 1, "visi": 3, "dan": 6, "misi": 3, "diusung": 1, "oleh": 1, "saja": 22, "mata": 15, "kuliah": 16, "di": 48, "dipelajari": 1, "utama": 2, "fasilitas": 10, "tersedia": 6, "apakah": 15, "memiliki": 2, "laboratorium": 5, "profil": 3, "lulusan": 8, "bisa": 3, "bekerja": 3, "mana": 4, "deskripsi": 2, "kapan": 8, "perkuliahan": 1, "dimulai": 1, "jadwal": 8, "akademik": 5, "uts": 3, "uas": 3, "diadakan": 1, "bagaimana": 11, "cara": 5, "menghubungi": 2, "ada": 11, "nomor": 1, "telepon": 1, "dimana": 2, "lokasi": 2, "menawarkan": 1, "beasiswa": 3, "mendapatkan": 1, "siapa": 4, "ketua": 1, "struktur": 2, "organisasi": 1, "daftar": 2, "dosen": 4, "sumber": 1, "pendanaan": 1, "dari": 1, "dana": 1, "berasal": 1, "detail": 1, "keuangan": 2, "lab": 1, "berapa": 3, "jumlah": 1, "ruang": 3, "kelas": 3, "layanan": 2, "digital": 1, "disediakan": 2, "online": 1, "mengakses": 1, "portal": 1, "sarana": 1, "prasarana": 1, "umum": 1, "untuk": 2, "mendukung": 2, "belajar": 2, "terbaru": 1, "berikan": 1, "kalender": 2, "libur": 3, "semester": 11, "kurikulum": 7, "kkni": 2, "menggunakan": 1, "obe": 4, "pengajar": 1, "profesor": 1, "biaya": 1, "rincian": 1, "ukt": 2, "sistem": 2, "mahasiswa": 3, "program": 7, "unggulan": 1, "fokus": 2, "khusus": 1, "andalan": 1, "mendaftar": 2, "informasi": 1, "pendaftaran": 1, "alur": 1, "masuk": 3, "ke": 2, "diimplementasikan": 1, "wajib": 2, "inti": 1, "baru": 1, "pilihan": 3, "tambahan": 1, "praktikum": 5, "2": 2, "4": 2, "mengajar": 1, "pemrograman": 1, "web": 1, "lanjutan": 1, "pengampu": 1, "basis": 1, "data": 1, "singkat": 1, "studi": 3, "tujuan": 1, "syarat": 1, "persyaratan": 1, "peluang": 2, "karir": 2, "relevan": 1, "dengan": 1, "kontak": 1, "mbkm": 3, "magang": 1, "pertukaran": 1, "awal": 2, "akhir": 2, "ganjil": 3, "2024": 4, "2025": 3, "genap": 2, "periode": 1, "registrasi": 1, "pembayaran": 1, "hari": 1, "nasional": 1, "kegiatan": 1}',
#  'word_docs': '{"hai": 1, "halo": 2, "pagi": 1, "selamat": 4, "siang": 1, "sore": 1, "hallo": 1, "hay": 1, "jumpa": 1, "sampai": 1, "tinggal": 1, "terimakasih": 4, "banyak": 1, "atas": 1, "bantuannya": 1, "membantu": 1, "sangat": 1, "usu": 95, "itu": 4, "apa": 55, "ti": 95, "tentang": 5, "jelaskan": 19, "ditawarkan": 1, "yang": 14, "misi": 3, "dan": 6, "visi": 3, "diusung": 1, "oleh": 1, "saja": 22, "kuliah": 16, "di": 48, "mata": 15, "dipelajari": 1, "utama": 2, "tersedia": 6, "fasilitas": 10, "memiliki": 2, "apakah": 15, "laboratorium": 5, "lulusan": 8, "profil": 3, "mana": 4, "bisa": 3, "bekerja": 3, "deskripsi": 2, "perkuliahan": 1, "kapan": 8, "dimulai": 1, "akademik": 5, "jadwal": 8, "diadakan": 1, "uts": 3, "uas": 3, "cara": 5, "menghubungi": 2, "bagaimana": 11, "ada": 11, "telepon": 1, "nomor": 1, "lokasi": 2, "dimana": 2, "beasiswa": 3, "menawarkan": 1, "mendapatkan": 1, "ketua": 1, "siapa": 4, "struktur": 2, "organisasi": 1, "dosen": 4, "daftar": 2, "pendanaan": 1, "sumber": 1, "berasal": 1, "dana": 1, "dari": 1, "keuangan": 2, "detail": 1, "lab": 1, "jumlah": 1, "berapa": 3, "kelas": 3, "ruang": 3, "layanan": 2, "disediakan": 2, "digital": 1, "online": 1, "mengakses": 1, "portal": 1, "sarana": 1, "prasarana": 1, "umum": 1, "untuk": 2, "belajar": 2, "mendukung": 2, "terbaru": 1, "berikan": 1, "kalender": 2, "semester": 11, "libur": 3, "kurikulum": 7, "kkni": 2, "obe": 4, "menggunakan": 1, "pengajar": 1, "profesor": 1, "biaya": 1, "ukt": 2, "rincian": 1, "sistem": 2, "mahasiswa": 3, "unggulan": 1, "program": 7, "khusus": 1, "fokus": 2, "andalan": 1, "mendaftar": 2, "informasi": 1, "pendaftaran": 1, "masuk": 3, "alur": 1, "ke": 2, "diimplementasikan": 1, "wajib": 2, "inti": 1, "baru": 1, "pilihan": 3, "tambahan": 1, "praktikum": 5, "2": 2, "4": 2, "lanjutan": 1, "web": 1, "mengajar": 1, "pemrograman": 1, "basis": 1, "data": 1, "pengampu": 1, "singkat": 1, "studi": 3, "tujuan": 1, "syarat": 1, "persyaratan": 1, "karir": 2, "peluang": 2, "dengan": 1, "relevan": 1, "kontak": 1, "mbkm": 3, "magang": 1, "pertukaran": 1, "ganjil": 3, "awal": 2, "akhir": 2, "2024": 4, "2025": 3, "genap": 2, "periode": 1, "registrasi": 1, "pembayaran": 1, "nasional": 1, "hari": 1, "kegiatan": 1}',
#  'index_docs': '{"84": 1, "54": 2, "85": 1, "27": 4, "86": 1, "87": 1, "88": 1, "89": 1, "91": 1, "90": 1, "92": 1, "28": 4, "93": 1, "94": 1, "95": 1, "97": 1, "96": 1, "2": 95, "29": 4, "3": 55, "1": 95, "22": 5, "6": 19, "98": 1, "10": 14, "36": 3, "20": 6, "35": 3, "99": 1, "100": 1, "5": 22, "7": 16, "4": 48, "8": 15, "101": 1, "55": 2, "21": 6, "14": 10, "56": 2, "9": 15, "23": 5, "15": 8, "37": 3, "30": 4, "38": 3, "39": 3, "57": 2, "102": 1, "16": 8, "103": 1, "24": 5, "17": 8, "104": 1, "40": 3, "41": 3, "25": 5, "58": 2, "11": 11, "12": 11, "106": 1, "105": 1, "60": 2, "59": 2, "42": 3, "107": 1, "108": 1, "109": 1, "31": 4, "61": 2, "110": 1, "32": 4, "62": 2, "112": 1, "111": 1, "115": 1, "114": 1, "113": 1, "63": 2, "116": 1, "117": 1, "118": 1, "43": 3, "45": 3, "44": 3, "64": 2, "65": 2, "119": 1, "120": 1, "121": 1, "122": 1, "123": 1, "124": 1, "125": 1, "66": 2, "68": 2, "67": 2, "126": 1, "127": 1, "69": 2, "13": 11, "46": 3, "18": 7, "70": 2, "33": 4, "128": 1, "129": 1, "130": 1, "131": 1, "71": 2, "132": 1, "72": 2, "47": 3, "133": 1, "19": 7, "134": 1, "73": 2, "135": 1, "74": 2, "136": 1, "137": 1, "48": 3, "138": 1, "75": 2, "139": 1, "76": 2, "140": 1, "141": 1, "49": 3, "142": 1, "26": 5, "77": 2, "78": 2, "146": 1, "145": 1, "143": 1, "144": 1, "148": 1, "149": 1, "147": 1, "150": 1, "50": 3, "151": 1, "152": 1, "153": 1, "80": 2, "79": 2, "155": 1, "154": 1, "156": 1, "51": 3, "157": 1, "158": 1, "52": 3, "81": 2, "82": 2, "34": 4, "53": 3, "83": 2, "159": 1, "160": 1, "161": 1, "163": 1, "162": 1, "164": 1}',
#  'index_word': '{"1": "ti", "2": "usu", "3": "apa", "4": "di", "5": "saja", "6": "jelaskan", "7": "kuliah", "8": "mata", "9": "apakah", "10": "yang", "11": "bagaimana", "12": "ada", "13": "semester", "14": "fasilitas", "15": "lulusan", "16": "kapan", "17": "jadwal", "18": "kurikulum", "19": "program", "20": "dan", "21": "tersedia", "22": "tentang", "23": "laboratorium", "24": "akademik", "25": "cara", "26": "praktikum", "27": "selamat", "28": "terimakasih", "29": "itu", "30": "mana", "31": "siapa", "32": "dosen", "33": "obe", "34": "2024", "35": "visi", "36": "misi", "37": "profil", "38": "bisa", "39": "bekerja", "40": "uts", "41": "uas", "42": "beasiswa", "43": "berapa", "44": "ruang", "45": "kelas", "46": "libur", "47": "mahasiswa", "48": "masuk", "49": "pilihan", "50": "studi", "51": "mbkm", "52": "ganjil", "53": "2025", "54": "halo", "55": "utama", "56": "memiliki", "57": "deskripsi", "58": "menghubungi", "59": "dimana", "60": "lokasi", "61": "struktur", "62": "daftar", "63": "keuangan", "64": "layanan", "65": "disediakan", "66": "untuk", "67": "mendukung", "68": "belajar", "69": "kalender", "70": "kkni", "71": "ukt", "72": "sistem", "73": "fokus", "74": "mendaftar", "75": "ke", "76": "wajib", "77": "2", "78": "4", "79": "peluang", "80": "karir", "81": "awal", "82": "akhir", "83": "genap", "84": "hai", "85": "pagi", "86": "siang", "87": "sore", "88": "hallo", "89": "hay", "90": "sampai", "91": "jumpa", "92": "tinggal", "93": "banyak", "94": "atas", "95": "bantuannya", "96": "sangat", "97": "membantu", "98": "ditawarkan", "99": "diusung", "100": "oleh", "101": "dipelajari", "102": "perkuliahan", "103": "dimulai", "104": "diadakan", "105": "nomor", "106": "telepon", "107": "menawarkan", "108": "mendapatkan", "109": "ketua", "110": "organisasi", "111": "sumber", "112": "pendanaan", "113": "dari", "114": "dana", "115": "berasal", "116": "detail", "117": "lab", "118": "jumlah", "119": "digital", "120": "online", "121": "mengakses", "122": "portal", "123": "sarana", "124": "prasarana", "125": "umum", "126": "terbaru", "127": "berikan", "128": "menggunakan", "129": "pengajar", "130": "profesor", "131": "biaya", "132": "rincian", "133": "unggulan", "134": "khusus", "135": "andalan", "136": "informasi", "137": "pendaftaran", "138": "alur", "139": "diimplementasikan", "140": "inti", "141": "baru", "142": "tambahan", "143": "mengajar", "144": "pemrograman", "145": "web", "146": "lanjutan", "147": "pengampu", "148": "basis", "149": "data", "150": "singkat", "151": "tujuan", "152": "syarat", "153": "persyaratan", "154": "relevan", "155": "dengan", "156": "kontak", "157": "magang", "158": "pertukaran", "159": "periode", "160": "registrasi", "161": "pembayaran", "162": "hari", "163": "nasional", "164": "kegiatan"}',
#  'word_index': '{"ti": 1, "usu": 2, "apa": 3, "di": 4, "saja": 5, "jelaskan": 6, "kuliah": 7, "mata": 8, "apakah": 9, "yang": 10, "bagaimana": 11, "ada": 12, "semester": 13, "fasilitas": 14, "lulusan": 15, "kapan": 16, "jadwal": 17, "kurikulum": 18, "program": 19, "dan": 20, "tersedia": 21, "tentang": 22, "laboratorium": 23, "akademik": 24, "cara": 25, "praktikum": 26, "selamat": 27, "terimakasih": 28, "itu": 29, "mana": 30, "siapa": 31, "dosen": 32, "obe": 33, "2024": 34, "visi": 35, "misi": 36, "profil": 37, "bisa": 38, "bekerja": 39, "uts": 40, "uas": 41, "beasiswa": 42, "berapa": 43, "ruang": 44, "kelas": 45, "libur": 46, "mahasiswa": 47, "masuk": 48, "pilihan": 49, "studi": 50, "mbkm": 51, "ganjil": 52, "2025": 53, "halo": 54, "utama": 55, "memiliki": 56, "deskripsi": 57, "menghubungi": 58, "dimana": 59, "lokasi": 60, "struktur": 61, "daftar": 62, "keuangan": 63, "layanan": 64, "disediakan": 65, "untuk": 66, "mendukung": 67, "belajar": 68, "kalender": 69, "kkni": 70, "ukt": 71, "sistem": 72, "fokus": 73, "mendaftar": 74, "ke": 75, "wajib": 76, "2": 77, "4": 78, "peluang": 79, "karir": 80, "awal": 81, "akhir": 82, "genap": 83, "hai": 84, "pagi": 85, "siang": 86, "sore": 87, "hallo": 88, "hay": 89, "sampai": 90, "jumpa": 91, "tinggal": 92, "banyak": 93, "atas": 94, "bantuannya": 95, "sangat": 96, "membantu": 97, "ditawarkan": 98, "diusung": 99, "oleh": 100, "dipelajari": 101, "perkuliahan": 102, "dimulai": 103, "diadakan": 104, "nomor": 105, "telepon": 106, "menawarkan": 107, "mendapatkan": 108, "ketua": 109, "organisasi": 110, "sumber": 111, "pendanaan": 112, "dari": 113, "dana": 114, "berasal": 115, "detail": 116, "lab": 117, "jumlah": 118, "digital": 119, "online": 120, "mengakses": 121, "portal": 122, "sarana": 123, "prasarana": 124, "umum": 125, "terbaru": 126, "berikan": 127, "menggunakan": 128, "pengajar": 129, "profesor": 130, "biaya": 131, "rincian": 132, "unggulan": 133, "khusus": 134, "andalan": 135, "informasi": 136, "pendaftaran": 137, "alur": 138, "diimplementasikan": 139, "inti": 140, "baru": 141, "tambahan": 142, "mengajar": 143, "pemrograman": 144, "web": 145, "lanjutan": 146, "pengampu": 147, "basis": 148, "data": 149, "singkat": 150, "tujuan": 151, "syarat": 152, "persyaratan": 153, "relevan": 154, "dengan": 155, "kontak": 156, "magang": 157, "pertukaran": 158, "periode": 159, "registrasi": 160, "pembayaran": 161, "hari": 162, "nasional": 163, "kegiatan": 164}'}

# %%
vocab_size = len(tokenizer.word_index)  # Menghitung jumlah kata unik dalam tokenizer
print('number of unique words = ', vocab_size)  # Menampilkan jumlah kata unik
# Out:
# number of unique words =  164

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

ptrn2seq = tokenizer.texts_to_sequences(df['patterns'])  # Mengonversi teks pola menjadi urutan angka
X = pad_sequences(ptrn2seq, padding='post')  # Melakukan padding terhadap urutan angka
print('X shape = ', X.shape)  # Menampilkan bentuk (shape) dari X

lbl_enc = LabelEncoder()  # Membuat objek LabelEncoder
y = lbl_enc.fit_transform(df['tag'])  # Mengonversi label kelas menjadi angka
print('y shape = ', y.shape)  # Menampilkan bentuk (shape) dari y
print('num of classes = ', len(np.unique(y)))  # Menampilkan jumlah kelas unik
# Out:
# X shape =  (137, 10)
# y shape =  (137,)
# num of classes =  46

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Embedding, LSTM, LayerNormalization, Dense, Dropout
from tensorflow.keras.utils import plot_model

model = Sequential()  # Membuat model Sequential

# Menambahkan lapisan-lapisan ke dalam model
model.add(Input(shape=(X.shape[1])))  # Lapisan input dengan bentuk sesuai dengan X
model.add(Embedding(input_dim=vocab_size+1, output_dim=100, mask_zero=True))  # Lapisan embedding dengan vocab_size + 1 sebagai input_dim
model.add(LSTM(32, return_sequences=True))  # Lapisan LSTM dengan 32 unit dan return_sequences=True
model.add(LayerNormalization())  # Lapisan normalisasi
model.add(LSTM(32, return_sequences=True))  # Lapisan LSTM kedua dengan 32 unit dan return_sequences=True
model.add(LayerNormalization())  # Lapisan normalisasi
model.add(LSTM(32))  # Lapisan LSTM ketiga dengan 32 unit
model.add(LayerNormalization())  # Lapisan normalisasi
model.add(Dense(128, activation="relu"))  # Lapisan dense dengan 128 unit dan fungsi aktivasi ReLU
model.add(LayerNormalization())  # Lapisan normalisasi
model.add(Dropout(0.2))  # Lapisan dropout dengan tingkat dropout 0.2
model.add(Dense(128, activation="relu"))  # Lapisan dense kedua dengan 128 unit dan fungsi aktivasi ReLU
model.add(LayerNormalization())  # Lapisan normalisasi
model.add(Dropout(0.2))  # Lapisan dropout kedua dengan tingkat dropout 0.2
model.add(Dense(len(np.unique(y)), activation="softmax"))  # Lapisan dense terakhir dengan jumlah unit sesuai dengan jumlah kelas dan fungsi aktivasi softmax

model.compile(optimizer='adam', loss="sparse_categorical_crossentropy", metrics=['accuracy'])  # Mengompilasi model dengan optimizer Adam, fungsi loss sparse_categorical_crossentropy, dan metrik akurasi

model.summary()  # Menampilkan ringkasan model
plot_model(model, show_shapes=True)  # Menampilkan struktur visual model
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 10, 100)           16500
#
#  lstm (LSTM)                 (None, 10, 32)            17024
#
#  layer_normalization (LayerN  (None, 10, 32)           64
#  ormalization)
#
#  lstm_1 (LSTM)               (None, 10, 32)            8320
#
#  layer_normalization_1 (Laye  (None, 10, 32)           64
#  rNormalization)
#
#  lstm_2 (LSTM)               (None, 32)                8320
#
#  layer_normalization_2 (Laye  (None, 32)               64
#  rNormalization)
#
#  dense (Dense)               (None, 128)               4224
#
#  layer_normalization_3 (Laye  (None, 128)              256
#  rNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  layer_normalization_4 (Laye  (None, 128)              256
#  rNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 46)                5934
#
# =================================================================
# Total params: 77,538
# Trainable params: 77,538
# Non-trainable params: 0
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model_history = model.fit(x=X,  # Data input X
                          y=y,  # Data output y
                          batch_size=10,  # Ukuran batch yang digunakan dalam setiap iterasi
                          callbacks=[tensorflow.keras.callbacks.EarlyStopping(monitor='accuracy', patience=3)],  # Menggunakan EarlyStopping untuk menghentikan pelatihan jika akurasi tidak meningkat setelah 3 epoch
                          epochs=50)  # Jumlah epoch (iterasi) pelatihan
# Out:
# Epoch 1/50
# 14/14 [==============================] - 0s 20ms/step - loss: 0.3569 - accuracy: 0.9124
# Epoch 2/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.2498 - accuracy: 0.9416
# Epoch 3/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2671 - accuracy: 0.9197
# Epoch 4/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.2157 - accuracy: 0.9562
# Epoch 5/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.2634 - accuracy: 0.9343
# Epoch 6/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.2149 - accuracy: 0.9489
# Epoch 7/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.2273 - accuracy: 0.9270

# %%
import re
import random

#case folding
def inputan_user(pattern):
    # Preprocess input pattern
    text = []
    txt = re.sub('[^a-zA-Z\']', ' ', pattern)  # Menghapus karakter selain huruf dan tanda kutip dari pattern
    txt = txt.lower()  # Mengonversi pattern menjadi huruf kecil
    txt = txt.split()  # Membagi pattern menjadi kata-kata
    txt = " ".join(txt)  # Menggabungkan kata-kata kembali menjadi teks
    text.append(txt)  # Menambahkan teks ke dalam list

    # Tokenize and pad the input pattern
    x_test = tokenizer.texts_to_sequences(text)  # Mengonversi teks input pengguna menjadi urutan angka
    x_test = np.array(x_test).squeeze()  # Mengonversi ke dalam array dan menghapus dimensi yang tidak perlu
    max_len = 50  # Menentukan panjang input maksimal untuk padding
    x_test = pad_sequences([x_test], padding='post', maxlen=X.shape[1])  # Melakukan padding terhadap urutan angka
    

    # Make prediction using the model
    y_pred = model.predict(x_test)  # Memprediksi kelas dengan model yang telah dilatih
    y_pred = y_pred.argmax()  # Mengambil indeks kelas dengan nilai probabilitas tertinggi
    tag = lbl_enc.inverse_transform([y_pred])[0]  # Mengonversi indeks kelas kembali menjadi label kelas
    responses = df[df['tag'] == tag]['responses'].values[0]  # Mengambil respons berdasarkan label kelas

    # Display user input and bot response
    print("User: {}".format(pattern))
    print(" BOT : {}".format(random.choice(responses)))  # Menampilkan respons bot secara acak dari respons yang tersedia

# %%
inputan_user('Selamat siang')
# Out:
# 1/1 [==============================] - 3s 3s/step
# User: Selamat siang
#  BOT : Hai! Apa yang ingin Anda ketahui tentang TI USU?

# %%
inputan_user('Sampai jumpa')
# Out:
# 1/1 [==============================] - 0s 37ms/step
# User: Sampai jumpa
#  BOT : Semoga melihat kamu kembali.

# %%
inputan_user('TI USU itu apa?')
# Out:
# 1/1 [==============================] - 0s 19ms/step
# User: TI USU itu apa?
#  BOT : Program Studi Teknologi Informasi di Universitas Sumatera Utara bertujuan untuk menghasilkan lulusan yang kompeten dalam bidang teknologi informasi dengan fokus pada data science dan intelligent systems.

# %%
inputan_user("Selamat siang")

# %%
inputan_user("Jelaskan visi TI USU")
# Out:
# 1/1 [==============================] - 0s 21ms/step
# User: Jelaskan visi TI USU
#  BOT : Visi TI USU: Menjadi Program Studi yang unggul dan professional dalam pengembangan ilmu pengetahuan bidang Teknologi Informasi dengan penekanan pada Data Science dan Intelligent Systems.

# %%
inputan_user("Good morning")

# %%
inputan_user("Good evening")

# %%
inputan_user("Selamat malam")

# %%
inputan_user("Helo")

# %%
inputan_user("Malam")

# %%
#Menyimpan model setelah pelatihan
model.save('my_model.keras')
